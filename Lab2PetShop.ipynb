# %% [markdown]
# <a href="https://colab.research.google.com/github/txd5297/Intro-for-ist210/blob/master/Lab2PetShop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Lab 2: Pet Shop

# %% [markdown]
# ![Lab2.png](data:image/png;base64,...)
